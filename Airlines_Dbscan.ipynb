# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score

# %%
df=pd.read_csv("/content/EastWestAirlines1.csv")

# %%
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df1=df.drop(['ID#'],axis=1)
df1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
ms=MinMaxScaler()

# %%
df2=pd.DataFrame(ms.fit_transform(df1),columns=df1.columns)

# %%
df2
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   float64
#  1   Qual_miles         3999 non-null   float64
#  2   cc1_miles          3999 non-null   float64
#  3   cc2_miles          3999 non-null   float64
#  4   cc3_miles          3999 non-null   float64
#  5   Bonus_miles        3999 non-null   float64
#  6   Bonus_trans        3999 non-null   float64
#  7   Flight_miles_12mo  3999 non-null   float64
#  8   Flight_trans_12    3999 non-null   float64
#  9   Days_since_enroll  3999 non-null   float64
#  10  Award?             3999 non-null   float64
# dtypes: float64(11)
# memory usage: 343.8 KB

# %%
dbscan=DBSCAN(eps=0.7,min_samples=5)
dbscan.fit_predict(df2)
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
df1['clusters']=dbscan.labels_

# %%
df1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#noisy datapoints
df1[df1['clusters']==-1]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3583   160114         500          1          1          1        71954
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3583           86              30817               53               1373
#
#       Award?  clusters
# 3583       1        -1

# %%
silhouette_score(df1,df1['clusters'])
# Out:
# 0.043217634046972625

# %%
df1.groupby("clusters").mean().reset_index()
# Out:
#    clusters        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0        -1  160114.000000  500.000000   1.000000   1.000000   1.000000
# 1         0   59807.839555   87.602462   1.705322   1.013900   1.008737
# 2         1   97010.442568  240.020946   2.662838   1.015541   1.018243
#
#     Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0  71954.000000    86.000000       30817.000000        53.000000
# 1  10227.689039     9.142971         226.292295         0.652502
# 2  28876.327703    15.735135         837.258108         2.565541
#
#    Days_since_enroll  Award?
# 0        1373.000000     1.0
# 1        3820.652105     0.0
# 2        4627.259459     1.0

# %%
plt.figure(figsize=(10,8))
plt.scatter(df1['clusters'],df1['Balance'],c=dbscan.labels_)
